# %%
# pip3 install cloudscraper beautifulsoup4
from bs4 import BeautifulSoup
import cloudscraper
import pandas as pd
import time
import re
from deep_translator import GoogleTranslator
from unidecode import unidecode
import json
from datetime import datetime, timedelta
import random
import requests
from langdetect import detect
from urllib.parse import urljoin
import os
import numpy as np

# %%
# Hàm để xử lý kiểu dữ liệu không serializable
def default_converter(o):
    if isinstance(o, (np.integer, np.floating)):  # Xử lý kiểu số NumPy
        return int(o)
    elif isinstance(o, (np.ndarray,)):           # Xử lý mảng NumPy (nếu có)
        return o.tolist()
    return str(o)  # Xử lý các kiểu dữ liệu khác

# %%
def get_company_name(soup):
    # Tìm thẻ h1 với class mong muốn
    company_name_tag = soup.find('h1', class_='sc-ca95509a-8 gcvyPj')
    # Kiểm tra nếu tìm thấy thẻ, trả về nội dung text
    if company_name_tag:
        return company_name_tag.get_text(strip=True)
    return None

# %%
def get_url(soup):
    canonical_tag = soup.find('link', rel='canonical')
    # Lấy giá trị của thuộc tính href
    if canonical_tag and 'href' in canonical_tag.attrs:
        canonical_url = canonical_tag['href']
        return canonical_url
    return None

# %%
def get_id_cong_ty(soup):
    url = get_url(soup)
    # Biểu thức chính quy tìm kiếm mã ID sau 'c'
    match = re.search(r'c(\d+)', url)
    if match:
        return match.group(1)  # Trả về kết quả khớp hoàn toàn 'c311795'
    return None

# %%
def get_company_info(soup):
    result = {"quyMo": None, "linhVuc": None, "lienHe": None}
    li_tags = soup.find_all('li', class_='sc-7f4c261d-6 ejuuLs')

    for li in li_tags:
        type_text = li.find('p', class_='type').get_text(strip=True)
        if type_text.lower() == "quy mô":
            result["quyMo"] = str(li.find('p', class_='text').get_text(strip=True))
        elif type_text.lower() == "lĩnh vực":
            result["linhVuc"] = str(li.find('p', class_='text').get_text(strip=True))
        elif type_text.lower() == "liên hệ":
            result["lienHe"] = str(li.find('p', class_='text').get_text(strip=True))
    # result["diaChi"] = soup.find('div', class_='dangerously-text').get_text(strip=True)
    return result

# %%
def get_logo(soup):
    try:
        # Tìm tag chứa ảnh logo
        style = soup.find("div", class_="sc-ca95509a-3 fbLezD").find("div").get('style')
        if not style:
            return None
        
        # Lấy link logo
        logo_url = re.search(r"url\('(.+?)'\)", style).group(1)
        output_folder="logos_vietnamworks"
        logo_url = urljoin('https://images.vietnamworks.com', logo_url)  # Hoàn thiện URL
        # print(logo_url)
        # Lấy id công ty
        company_id = get_id_cong_ty(soup)  # Hàm này do bạn cung cấp
        
        # Tạo tên file và thư mục lưu
        filename = f"logo_{company_id}.jpg"
        os.makedirs(output_folder, exist_ok=True)
        file_path = os.path.join(output_folder, filename)
        
        # Tải ảnh từ link
        response = requests.get(logo_url, stream=True)
        with open(file_path, "wb") as f:
            for chunk in response.iter_content(1024):
                f.write(chunk)
        return logo_url
    
    except Exception as e:
        return f"Lỗi: {str(e)}"

# %%
def get_dia_chi(soup):
    # Tìm thẻ <script> có id="__NEXT_DATA__"
    script_tag = soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
    
    if script_tag:
        # Parse nội dung JSON trong thẻ <script>
        try:
            data = json.loads(script_tag.string)
            company_info = data.get('props', {}).get('pageProps', {}).get('companyProfile', {}).get('address')
            return company_info
        except json.JSONDecodeError:
            print("Không thể phân tích JSON.")
            return None
    else:
        print("Không tìm thấy thẻ <script> chứa JSON.")
        return None

# %%
def convert_to_camel_case(text):
    # Chuyển tất cả chữ về thường
    text = unidecode(text.lower())
    # Tách các từ dựa trên khoảng trắng
    words = text.split()
    # Viết hoa chữ cái đầu của từng từ và nối chúng lại
    camel_case = ''.join(word.capitalize() for word in words)
    return camel_case

# %%
def get_phuc_loi(soup):
    result = []
    data = soup.find_all('div', class_="sc-eifrsQ huJZbu")
    
    for temp in data:
        # Tìm thẻ h4 (key)
        obj = temp.find('h4')
        # Tìm thẻ div chứa value
        value = temp.find('div', class_="sc-d6a527f2-6 gsnZik")
        
        # Lấy nội dung text nếu tồn tại
        obj_text = obj.get_text(strip=True) if obj else None
        value_text = value.get_text(strip=True) if value else None
        
        # Thêm vào từ điển nếu cả obj và value tồn tại
        if obj_text and value_text:
            # Thêm đối tượng theo cấu trúc yêu cầu vào result
            result.append({
                "Name": obj_text,
                "Description": value_text
            })
    
    return result

# %%
def get_gioi_thieu(soup):
    # Tìm thẻ <script> có id="__NEXT_DATA__"
    script_tag = soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
    
    if script_tag:
        # Parse nội dung JSON trong thẻ <script>
        try:
            data = json.loads(script_tag.string)
            company_info = data.get('props', {}).get('pageProps', {}).get('companyProfile', {}).get('companyProfile')
            return company_info
        except json.JSONDecodeError:
            print("Không thể phân tích JSON.")
            return None
    else:
        print("Không tìm thấy thẻ <script> chứa JSON.")
        return None

# %%
# output = []
# for temp in range(0,100):
# # for temp in UrlCongTy:
#     while True:
#         try:
#             ids = 4018 + temp
#             scraper = cloudscraper.create_scraper(
#                             browser={
#                                 "browser": "chrome",
#                                 "platform": "windows",
#                             },
#                         )
#             # specify the target URL
#             url = f"https://www.vietnamworks.com/nha-tuyen-dung/abc-solutions-c{ids}?fromPage=jobDetail"
#             # url = temp
#             response = scraper.get(url)
#             print(response.status_code, ids)
#             if response.status_code == 200:
#                 soup = BeautifulSoup(response.text, 'html.parser')
#                 if get_id_cong_ty(soup):
#                     data = {
#                         'Url': str(get_url(soup) + "?fromPage=jobDetail"),
#                         'ID': int(get_id_cong_ty(soup)),
#                         'Logo': str(get_logo(soup)),
#                         'Name': str(get_company_name(soup)),
#                         'CompanySize': get_company_info(soup).get('quyMo'),
#                         'Field': get_company_info(soup).get('linhVuc'),
#                         'Contact': get_company_info(soup).get('lienHe'),
#                         'CompanyIntroduction': str(get_gioi_thieu(soup)),
#                         'CompanyAddress': str(get_dia_chi(soup)),
#                         'Welfare': get_phuc_loi(soup),
#                     }
#                     output.append(data)
#                     print(json.dumps(data, ensure_ascii=False, indent=5, default=default_converter))
#                     print(response.status_code, "Cập nhật thông tin thành công.", ids, len(output))
#             if response.status_code == 429:
#                     # print(f"ID {ids}: Too many requests, retrying...")
#                 time.sleep(random.randint(1, 5))  # Chờ một khoảng thời gian trước khi thử lại
#             else:
#                 break  # Thoát khỏi vòng lặp nếu không phải 429
#         except (requests.exceptions.ConnectionError, requests.exceptions.Timeout) as e:
#             print(f"ID {ids}: Lỗi kết nối {e}. Đang thử lại...")
#             time.sleep(random.randint(1, 5))  # Chờ thêm trước khi thử lại

# %%
# Đường dẫn tới file JSON
file_path = 'sample_vietnamworks_28_11_2024_2.json'

# Đọc file JSON
with open(file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Hiển thị dữ liệu đã đọc
# print(data)
UrlCongTy = []
for temp in data:
    UrlCongTy.append(temp.get('UrlCongTy'))

# %%
output = []
# for temp in range(0,100):
for temp in UrlCongTy:
    while True:
        try:
            # ids = 299405 + temp
            scraper = cloudscraper.create_scraper(
                            browser={
                                "browser": "chrome",
                                "platform": "windows",
                            },
                        )
            # specify the target URL
            # url = f"https://www.vietnamworks.com/nha-tuyen-dung/abc-solutions-c{ids}?fromPage=jobDetail"
            url = temp
            response = scraper.get(url)
            print(response.status_code, int(get_id_cong_ty(soup)))
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')
                if get_id_cong_ty(soup):
                    data = {
                        'Url': str(get_url(soup)+ "?fromPage=jobDetail"),
                        'ID': int(get_id_cong_ty(soup)),
                        'Logo': str(get_logo(soup)),
                        'Name': str(get_company_name(soup)),
                        'CompanySize': get_company_info(soup).get('quyMo'),
                        'Field': get_company_info(soup).get('linhVuc'),
                        'Contact': get_company_info(soup).get('lienHe'),
                        'CompanyIntroduction': str(get_gioi_thieu(soup)),
                        'CompanyAddress': str(get_dia_chi(soup)),
                        'Welfare': get_phuc_loi(soup),
                    }
                    output.append(data)
                    print(json.dumps(data, ensure_ascii=False, indent=5, default=default_converter))
                    print(response.status_code, "Cập nhật thông tin thành công.", int(get_id_cong_ty(soup)), len(output))
            if response.status_code == 429:
                    # print(f"ID {ids}: Too many requests, retrying...")
                time.sleep(random.randint(1, 5))  # Chờ một khoảng thời gian trước khi thử lại
            else:
                break  # Thoát khỏi vòng lặp nếu không phải 429
        except (requests.exceptions.ConnectionError, requests.exceptions.Timeout) as e:
            print(f"ID {ids}: Lỗi kết nối {e}. Đang thử lại...")
            time.sleep(random.randint(1, 5))  # Chờ thêm trước khi thử lại
# Out:
# 200 395774
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/thornton-tomasetti-vietnam-c261563?fromPage=jobDetail",
#      "ID": 261563,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/8a/11128523.png",
#      "Name": "Thornton Tomasetti Vietnam",
#      "CompanySize": null,
#      "Field": "Kỹ thuật xây dựng/Cơ sở hạ tầng",
#      "Contact": "Kevin Dang",
#      "CompanyIntroduction": "Thornton Tomasetti provides engineering design, investigation and analysis services to clients worldwide on projects of every size and level of complexity.  We are a growing 1700+ person firm with 10 practices: Structural Engineering, Forensics, Applied Science, Renewal, Property Loss Consulting, Construction Engineering, Protective Design and Security, Facade Engineering, Sustainability and Transportation. We work on everything from landmark buildings to small-scale specialty structures, from the historic to the high performing, while balancing multiple objectives, including form, function, schedule, sustainability, constructability and budget. TALENT is at the core of our business.\r\n\r\nThe Ho Chi Minh office is currently looking for a talented individual to serve as a BIM Modeler on our project design team. This individual will create project deliverable 3D models and 2D drawings using Autodesk Revit as well as TT’s suite of internally developed interoperability tools. The ideal candidate is knowledgeable and passionate about BIM and associated technologies, passionate about building structural systems and is able to work in an independent and self-directed manner.\r\n\r\nThornton Tomasetti is proud to be an equal employment workplace. Individuals seeking employment at Thornton Tomasetti are considered without regards to age, ancestry, color, gender (including pregnancy, childbirth, or related medical conditions), gender identity or expression, genetic information, marital status, medical condition, mental or physical disability, national origin, protected family care or medical leave status, race, religion (including beliefs and practices or the absence thereof), sexual orientation, military or veteran status, or any other characteristic protected by federal, state, or local laws.",
#      "CompanyAddress": "Suite 601+606, 6th Floor, Saigon Royal Building, 91 Pasteur Street, Ben Nghe Ward, District 1, Ho Chi Minh City",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Salary will be commensurate with qualifications and experience"
#           },
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Social insurance, health insurance, unemployment insurance according to Labor Laws"
#           },
#           {
#                "Name": "Hoạt động nhóm",
#                "Description": "Professional, dynamic working environment"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 261563 1
# 200 261563
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/nam-an-holdings-c326737?fromPage=jobDetail",
#      "ID": 326737,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/56/11089784.png",
#      "Name": "Nam An Holdings",
#      "CompanySize": null,
#      "Field": "Sản xuất",
#      "Contact": "Ms.Trinh",
#      "CompanyIntroduction": "Nam An Corporation is a  group (located in Hiep Phuoc, Nha Be), which manages 5 companies in hospitality industry, comprising BT International (www.btcorp.com.vn), FNB Concepts (www.fnb-concepts.com), located in District 3 and District 7, Klaus refrigeration company (https://www.linkedin.com/company/klaus-refrigeration) located in Hiep Phuoc - Nha Be, a stainless steel fabrication factory (Schroder located in Nhon Trach, Dong Nai) and School for Hospitality Professionals (www.shp.edu.vn) located in District 3..",
#      "CompanyAddress": "Hiep Phuoc industrial zone, Lot F14-4, Road No.24, 700000",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Lương tháng 13, Hoa Hồng, Xe đưa đón, Đào tạo"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 326737 2
# 200 326737
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/navigos-search-c751?fromPage=jobDetail",
#      "ID": 751,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/ee/11272016.png",
#      "Name": "Navigos Search",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Cung cấp nhân lực",
#      "Contact": "Navigos Search",
#      "CompanyIntroduction": "Navigos Search is the leading, most experienced and highly qualified executive recruitment firm in Vietnam. Our mission is to help people and companies achieve their dream. We do this by matching talented individuals to the jobs for which they are best suited, ensuring that our clients have the right people on board that they need to succeed, and our candidates land the job of their dream. We accomplish this mission thanks to our strong expertise in local labor market, an established and broad network of clients and candidates and a proven recruitment method of international standards.",
#      "CompanyAddress": "HCMC",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Attractive salary & compensation package"
#           },
#           {
#                "Name": "Khác",
#                "Description": "Global working environment"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 751 3
# 200 751
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-tnhh-ola-investments-c378480?fromPage=jobDetail",
#      "ID": 378480,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/6e/11230344.png",
#      "Name": "CÔNG TY TNHH OLA INVESTMENTS",
#      "CompanySize": "25-99 nhân viên",
#      "Field": "Dịch vụ lưu trú/Nhà hàng/Khách sạn/Du lịch",
#      "Contact": "HR Ola Hale",
#      "CompanyIntroduction": "Hawai'i, where we come from, is a place of aloha and blessings. It's a place where we welcome each other with a smile, where we embrace the spirit of 'ohana (family) and where we celebrate the beauty of life. \"Ola\" means alive or a good wish of health and well-being, and \"Hale\" means home. In Hawaiian, Ola Hale means a well-being home. To us, Ola Hale Restaurant and Bar is more than a place to eat and drink, it's a welcoming home to everyone who visits us.",
#      "CompanyAddress": "270 Hai Bà Trưng, Tan Dinh, District 1, Ho Chi Minh City, Vietnam",
#      "Welfare": [
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "For Self"
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "12 Days per annum"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 378480 4
# 200 378480
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-tnhh-tmt-energy-c395774?fromPage=jobDetail",
#      "ID": 395774,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/d4/11331959.png",
#      "Name": "CÔNG TY TNHH TMT ENERGY",
#      "CompanySize": null,
#      "Field": "Sản xuất và Phân phối Điện/Khí đốt/Nước",
#      "Contact": "HR Department",
#      "CompanyIntroduction": "Chuyên về phát triển kinh doanh, thực hiện và quản lý các dự án Năng lượng tái tạo, tập trung vào sản xuất, phân phối và lưu trữ điện mặt trời, bao gồm:\r\n1. Quản lý và thực hiện giao dịch\r\n2. Cấu trúc tài chính và tìm nguồn cung ứng\r\n3. Cung cấp các giải pháp kỹ thuật và thiết kế hệ thống\r\n4. PM và O&M\r\n5. Giao dịch (Thiết bị năng lượng mặt trời)\r\n6. Dịch vụ tư vấn kỹ thuật năng lượng mặt trời",
#      "CompanyAddress": "18 Đường Trần Ngọc Diện, Phường Thảo Điền, Thành phố Thủ Đức, TP Hồ Chí Minh",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Lương tháng 13, phụ cấp"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 395774 5
# 200 395774
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/british-university-vietnam-buv-c108538?fromPage=jobDetail",
#      "ID": 108538,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/40/10303550.png",
#      "Name": "British University Vietnam (BUV)",
#      "CompanySize": "100-499 nhân viên",
#      "Field": "Giáo dục/Đào Tạo",
#      "Contact": "Human Resources Department",
#      "CompanyIntroduction": "British University Vietnam (BUV) is the first and only international university in Vietnam to directly award British degrees from the prestigious University of London and Staffordshire University. BUV is rated a 5 Star university of excellence by the world recognised QS accreditor and is also recognised with a University-wide accreditation from the UK’s Quality Assurance Agency (QAA).\r\n\r\nBUV has three main brand drivers:\r\n\r\n•\tOffering accredited British and international higher education and training in Vietnam.\r\n•\tProviding 5-star university campuses, learning spaces, and services.\r\n•\tIncluding a compulsory personal and social growth program that prepares students for the future of life and work.\r\n\r\nEstablished in 2009, BUV provides teaching for undergraduate and graduate programmes. Employability rates for students are exceptionally high with 100% of graduates from BUV either employed or continuing higher education within 3 months after graduation.\r\n\r\nWith a wide network of more than 300 enterprise partners in various fields, and 12-week internship programmes, BUV helps students gain professional knowledge and practical skills to meet employers’ requirements as well as be ready to develop their careers immediately after graduation.\r\n\r\nStudents study at BUV’s award winning campus in the Ecopark township near Hanoi. With its state-of-the-art teaching and learning facilities and an iconic design, BUV is recognised as one of the best educational environments in South East Asia.\r\n\r\nFor more details, please visit our website at https://www.buv.edu.vn/",
#      "CompanyAddress": "Ecopark campus, Ecopark Township, Van Giang District, Hung Yen",
#      "Welfare": [
#           {
#                "Name": "Employee recognition program",
#                "Description": "Reward outstanding behavior in the workplace"
#           },
#           {
#                "Name": "Health care plan",
#                "Description": "Insurance, Annual health care"
#           },
#           {
#                "Name": "Salary",
#                "Description": "Highly competitive salary, annual salary review and bonus"
#           },
#           {
#                "Name": "Working environment",
#                "Description": "International Working environment, Flexible working arrangement and working away from campus."
#           },
#           {
#                "Name": "Training",
#                "Description": "Training and development"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 108538 6
# 200 108538
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/tdcx-thailand-c294813?fromPage=jobDetail",
#      "ID": 294813,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/d3/11129434.png",
#      "Name": "TDCX Thailand",
#      "CompanySize": null,
#      "Field": "Khác",
#      "Contact": "Recruitment Team",
#      "CompanyIntroduction": "Who is TDCX?\r\n\r\nTDCX (NYSE: TDCX) provides transformative digital CX solutions, enabling world-leading and disruptive brands to acquire new customers, build customer loyalty, and protect their online communities.\r\n\r\nTDCX helps clients, including many of the world’s best brands, achieve their customer experience aspirations by harnessing technology, human intelligence, and our global footprint. We serve clients in fintech, gaming, technology, home sharing and travel, digital advertising and social media, streaming, and e-commerce. Our expertise and strong footprint in Asia have made us a trusted partner for clients, particularly high-growth, new economy companies looking to tap the region’s growth potential.\r\n\r\nWe pride ourselves on discovering and employing the best professionals to join us as we transform the outsourced CX industry. Our commitment to #BeMore for our people, our clients, and our community has led to us winning more than 350 industry awards, including being one of the best companies to work for in Asia.\r\n\r\nFrom our first-rate workspaces, above-industry-average compensation packages, career opportunities, to our workplace perks, find out what else is in store when you embark on a career with TDCX.",
#      "CompanyAddress": "United Center Building,  323 Silom Road, Bangrak,  Bangkok 10500, Thailand",
#      "Welfare": [
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Medical Insurance Coverage"
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "10 days anual paid leave and 13 days public holiday"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Training in English"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 294813 7
# 200 294813
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-co-phan-thuong-mai-va-cong-nghe-tst-viet-nam-c341598?fromPage=jobDetail",
#      "ID": 341598,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/30/11256825.png",
#      "Name": "CÔNG TY CỔ PHẦN THƯƠNG MẠI VÀ CÔNG NGHỆ TST VIỆT NAM",
#      "CompanySize": "25-99 nhân viên",
#      "Field": "Sản xuất",
#      "Contact": "Phòng Nhân Sự",
#      "CompanyIntroduction": "Công ty Cổ phần Thương Mại và Công Nghệ TST Việt Nam là đại lý ủy quyền SKF, công ty số 1 thế giới về vòng bi. Sản phầm chính của hãng gồm: Vòng bi SKF, Gối đỡ SKF, Thiết bị truyền đồng SKF, Gioăng phớt SKF, Dây đai SKF, Dụng cụ bảo trì SKF, Mỡ bôi trơn SKF, Đĩa xích, xích công nghiệp, khớp nối, ống lót côn, pulley SKF.\r\n\r\nĐược sự tín nhiệm và tin tưởng của SKF là công ty số 1 thế giới về vòng bi hỗ trợ. Công ty chúng tôi gồm đội ngũ nhân viên bán hàng, hỗ trợ kỹ thuật hoạt động lâu năm trong lĩnh vực phân phối và dịch vụ kỹ thuật cam kết mang đến cho khách hàng sản phẩm chính hãng và dịch vụ hỗ trợ khách hàng tốt nhất.\r\n\r\nĐể sử dụng đúng sản phẩm và dịch vụ SKF chính hãng, Quý khách hãy liên hệ với đại lý SKF, Công ty CP Thương mại và Công nghệ TST Việt Nam.\r\n\r\nwebsite: www.vongbicongnghiep.vn; www.tstvietnam.vn",
#      "CompanyAddress": "Số E24/68 đường Trung Kính, Cầu Giấy, Hà Nội",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Lương: 8 -15 triệu ( đàm phán trực tiếp khi phỏng vấn theo năng lực )"
#           },
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Gói khám bệnh định kỳ cho NV 1 năm/ lần"
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "Được đóng BHXH, BHYT, BHTN,"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 341598 8
# 200 341598
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/navigos-searchs-client-c192082?fromPage=jobDetail",
#      "ID": 192082,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/22/11234686.png",
#      "Name": "Navigos Search's Client",
#      "CompanySize": "500-999 nhân viên",
#      "Field": "Cung cấp nhân lực",
#      "Contact": null,
#      "CompanyIntroduction": "Established in 2003, Navigos Search is the leading and largest provider of Executive Search Services and HR Solutions in Vietnam. We offers a variety of talent acquisition solutions to clients, ranging from contingent permanent recruitment, retained executive search, recruitment process outsourcing and management consultancy.\r\n\r\nUnder Navigos Group, our mission is helping people and companies achieve their dreams. We accomplish this mission thanks to our largest team of experienced, skillful and industry-specialized consultants, our extensive nationwide database of high-profile executives, and a proven recruitment method of international standards..",
#      "CompanyAddress": "Hanoi",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "13th monthly salary, Performance Bonus"
#           },
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Healthcare Plan and Insurance package"
#           },
#           {
#                "Name": "Khác",
#                "Description": "Professional FDI working environment"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 192082 9
# 200 192082
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-tnhh-bao-hiem-nhan-tho-prudential-viet-nam-c317589?fromPage=jobDetail",
#      "ID": 317589,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/3a/11186692.png",
#      "Name": "Công Ty TNHH Bảo Hiểm Nhân Thọ Prudential Việt Nam",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Bảo hiểm",
#      "Contact": "Phát Triển Lực Lượng Bán Hàng",
#      "CompanyIntroduction": "-PRUVenture with Prudential-\r\nKể từ khi chính thức hoạt động vào năm 2019, PruVenture được Prudential Việt Nam chú trọng đầu tư, xây dựng để trở thành hình mẫu của mô hình phát triển chuyên viên hoạch định tài chính toàn thời gian trên thị trường. Với sự đồng hành từ những chuyên gia trong lĩnh vực tài chính – bảo hiểm, các bạn trẻ sẽ bắt đầu hành trình sự nghiệp tại PruVenture theo lộ trình đào tạo chuyên sâu, được hỗ trợ tài chính và đầu tư toàn diện bằng những công cụ hiện đại.\r\n\r\n-Prudential-\r\nĐược thành lập tại London vào năm 1848, Prudential Plc là một trong những tập đoàn dịch vụ tài chính bán lẻ hàng đầu thế giới đã cung cấp bảo hiểm nhân thọ, dịch vụ tài chính và các sản phẩm quản lý tài sản trên khắp Vương quốc Anh, Hoa Kỳ và Châu Á trong hơn 165 năm. Từ năm 1923, Prudential đã có một lịch sử phong phú và rộng lớn ở Châu Á. Prudential hiện đang hoạt động tại 14 quốc gia châu Á bao gồm Malaysia, Singapore, Hồng Kông, Thái Lan, Indonesia, Campuchia, Philippines, Ấn Độ, Đài Loan, Việt Nam, Trung Quốc, Nhật Bản, Hàn Quốc và UAE.\r\n\r\nXuất hiện lần đầu tại Việt Nam vào năm 1995 và chính thức bắt đầu hoạt động vào năm 1999 với phương châm “Luôn luôn lắng nghe. Luôn luôn thấu hiểu”, Prudential Việt Nam đã trở thành tập đoàn tiên phong trong lĩnh vực bảo hiểm nhân thọ với một loạt các sản phẩm và sáng kiến mới. Hệ thống kinh doanh của Prudential Việt Nam trải dài trên toàn quốc với hơn 300 trung tâm chăm sóc khách hàng và chi nhánh đặt tại 63 tỉnh, thành phố Việt Nam nhờ sự hợp tác với 07 ngân hàng đối tác.\r\n\r\nTheo chiến lược 2019 đến 2021, đầu năm 2019, Prudential ra mắt logo và khẩu hiệu mới \"\"Lắng nghe, thấu hiểu và hành động\"\". Thương hiệu mới một lần nữa củng cố cam kết lấy khách hàng là trọng tâm và tập trung vào kết nối con người, sự đơn giản và đổi mới trong mọi hoạt động kinh doanh.",
#      "CompanyAddress": "Saigon Trade Center, 37 Ton Duc Thang, District 1, HCMC",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Thu nhập cạnh tranh lên đến 48 triệu (trợ cấp kinh doanh + trợ cấp hoạt động + hoa hồng)"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Được đào tạo chuyên sâu + cung cấp công cụ phân tích hiện đại"
#           },
#           {
#                "Name": "Du lịch",
#                "Description": "Cơ hội du lịch trong và ngoài nước"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 317589 10
# 200 317589
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-co-phan-tap-doan-phu-thai-holdings-c345752?fromPage=jobDetail",
#      "ID": 345752,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/61/11064177.png",
#      "Name": "Công Ty Cổ Phần Tập Đoàn Phú Thái Holdings",
#      "CompanySize": "100-499 nhân viên",
#      "Field": "Khác",
#      "Contact": "Phạm Thị Kim Thoa",
#      "CompanyIntroduction": "CÔNG TY CỔ PHẦN TẬP ĐOÀN PHÚ THÁI HOLDINGS",
#      "CompanyAddress": "19/192 Thái Thịnh, Phường Láng Hạ, Quận Đống Đa, Hà Nội",
#      "Welfare": [
#           {
#                "Name": ".",
#                "Description": "Lương tháng 13 cố định + thưởng theo hiệu quả kinh doanh năm/ dự án"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 345752 11
# 200 345752
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-co-phan-tap-doan-th-c80449?fromPage=jobDetail",
#      "ID": 80449,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/15/11121593.png",
#      "Name": "Công Ty Cổ Phần Tập Đoàn TH",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Hàng tiêu dùng",
#      "Contact": "HR Department",
#      "CompanyIntroduction": "TH Group được thành lập dưới sự tư vấn tài chính của Ngân hàng TMCP Bắc Á. Ngân hàng được thành lập từ năm 1994 tại tỉnh Nghệ An, Việt Nam.\r\n\r\nĐịnh hướng phát triển của TH Group là trở thành một Tập Đoàn hàng đầu Việt Nam cung cấp sản phẩm sạch, tinh túy từ thiên nhiên bằng sự kết hợp giữa tự nhiên và đẵng cấp công nghệ cao . Đó là các sản phẩm Sữa tươi sạch, tinh túy được cung cấp từ hệ thống Trang trại chăn nuôi Bò sữa tập trung quy mô công nghiệp với sự hoàn hảo của quy trình chăn nuôi bò theo công nghệ hiện đại nhất thế giới; ngoài ra còn có các sản phẩm rau, củ, quả… được sản xuất trong điều kiện môi trường sạch tự nhiên, đang là mối quan tâm hang đầu của nhiều người dân hiện nay.",
#      "CompanyAddress": "Số 60 Lý Thái Tổ, Hoàn Kiếm, Hà Nội",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Thưởng các dịp lễ tết, thưởng thâm niên,..."
#           },
#           {
#                "Name": "Sức khỏe",
#                "Description": "Khám sức khỏe định kỳ"
#           },
#           {
#                "Name": "Phát triển sự nghiệp",
#                "Description": "- Cơ hội thăng tiến \n- Học tập và phát triển  \n- Tham gia các hoạt động trách nhiệm xã hội"
#           },
#           {
#                "Name": "Wellbeing",
#                "Description": "- Team Building \n- Niềm tự hào thương hiệu \n- Các hoạt động phong phú"
#           },
#           {
#                "Name": "Môi trường",
#                "Description": "- Môi trường hòa nhập \n- Đồng nghiệp gắn kết"
#           },
#           {
#                "Name": "Bảo hiểm",
#                "Description": "Bảo hiểm chăm sóc sức khỏe, bảo hiểm xã hội, bảo hiểm rủi ro, bảo hiểm tai nạn,...."
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 80449 12
# 200 80449
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-co-phan-chung-khoan-ssi-c17942?fromPage=jobDetail",
#      "ID": 17942,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/46/11025407.png",
#      "Name": "Công Ty Cổ Phần Chứng Khoán SSI",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Chứng khoán",
#      "Contact": "SSI Tuyển dụng",
#      "CompanyIntroduction": "SSI - định chế tài chính hàng đầu và uy tín tại Việt Nam , với tiềm lực tài chính vững mạnh, đội ngũ cán bộ hùng hậu, chuyên nghiệp, SSI luôn cung cấp cho khách hàng các sản phẩm, dịch vụ vượt trội và luôn đảm bảo tối đa lợi ích cổ đông. SSI là cửa ngõ vào thị trường của các nhà đầu tư quốc tế với nhiều họat động kết nối và có mạng lưới hoạt động rộng tại những thành phố lớn như Hà Nội, TP. Hồ Chí Minh, Hải Phòng, Nha Trang SSI liên tục được vinh danh với các giải thưởng quan trọng mang tầm cỡ quốc tế: “The Best Fund house in Vietnam”, “Best Broker in Vietnam”, “Best Investment Bank”… bởi Asia Asset Management,  Asian Investor và Finance Asia…..\r\n\r\nSSI không chỉ đem lại cho bạn một môi trường làm việc chuyên nghiệp, luôn có cơ hội nâng cao chuyên môn nghiệp vụ, mà còn quan tâm đến việc liên tục nâng cao đời sống tinh thần và vật chất mang lại sự phát triển toàn diện của bạn với các chế độ phúc lợi  hấp dẫn:\r\n•\tChính sách lương minh bạch gắn với sự đóng góp của từng vị trí đối với tổ chức, tương xứng với năng lực nhân viên và tạo tính cạnh tranh so với thị trường\r\n•\tChính sách phúc lợi toàn diện và thưởng hấp dẫn & cạnh tranh nhất trên thị trường Tham gia các khóa đào tạo, nâng cao kỹ năng theo từng giai đoạn của sự nghiệp\r\n•\tChính sách tuyển dụng minh bạch với nhiều cơ hội thăng tiến\r\n•\tHoạt động gắn kết phong phú tạo nên “The great work place” tại SSI\r\n\r\nVà còn nhiều nữa những quyền lợi chờ bạn khám phá khi trở thành thành viên của Ngôi nhà chung SSI.\r\nĐiều đầu tiên hãy làm ngay đó là: Tham khảo vị trí dưới đây & gửi hồ sơ ứng tuyển về cho chúng tôi nhé!",
#      "CompanyAddress": "1C Ngô Quyền - Hoàn Kiếm - Hà Nội",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Lương, thưởng cạnh tranh tương xứng với năng lực và kinh nghiệm làm việc."
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Được tham gia các chương trình đào tạo của Công ty."
#           },
#           {
#                "Name": "Khác",
#                "Description": "Làm việc trong môi trường chuyên nghiệp, năng động"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 17942 13
# 200 17942
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/panko-hcm-office-c363216?fromPage=jobDetail",
#      "ID": 363216,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/5c/11222188.png",
#      "Name": "PANKO HCM OFFICE",
#      "CompanySize": "25-99 nhân viên",
#      "Field": "Dệt may/May mặc/Giày dép",
#      "Contact": "MOON (Ms)",
#      "CompanyIntroduction": "We've established a new office in HCM, and hiring new members for many teams. \r\nThe office is a managing entity with independent decisions on top of our factories. \r\n\r\n1.      Company Profile : Panko: fashion vertical manufacturing company  \r\nPlease visit, http://www-e.panko.co.kr/\r\n2.      Office Address: LIM Tower, 9-11 Ton Duc Thang, Ben Nghe Ward, District 1, HCMC, \r\n3.      Working hour :  Monday~ Friday (8:00 ~ 17:30)",
#      "CompanyAddress": ".9-11 Ton Duc Thang, Ben Nghe Ward, District 1, HCMC",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "13 Month Salary (Basis salary+ allowance)"
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "Annual leave as Labor law"
#           },
#           {
#                "Name": "Laptop",
#                "Description": "New laptop provided indivisually"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 363216 14
# 200 363216
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/navigos-group-c18364?fromPage=jobDetail",
#      "ID": 18364,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/6e/10922087.png",
#      "Name": "Navigos Group",
#      "CompanySize": "500-999 nhân viên",
#      "Field": "Cung cấp nhân lực",
#      "Contact": "Talent Acquisition Team",
#      "CompanyIntroduction": "Navigos Group is a company dedicated to helping people and companies achieve their dreams through our professional recruiting services. Our main portfolio of companies are the leading players in the recruitment industry in Vietnam. The group is comprised of www.VietnamWorks.com, an online recruitment portal and Navigos Search, an executive search firm.\r\nNow on our 22th year operating in Vietnam, Navigos Group’s greatest asset is the largest and most comprehensive database of Vietnamese professionals. Known for our strong service culture and people-centric management, we have maintained our status as the leading recruiting service in Vietnam since our foundation in 2002. \r\nThe consistent growth of our company - then a local Vietnamese company, accelerated in 2013 when Navigos Group was acquired by en-Japan, one of the leading recruitment firms in the region.",
#      "CompanyAddress": "HCM Office: 20th Floor, E Town Central - 11 Doan Van Bo, Ward 13, District 4; Hanoi office: 8th Floor, V Building, 125-127 Ba Trieu St, Hai Ba Trung District",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Attractive commission scheme"
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "27 paid leave"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Powerful supporting tools (Unlimited VietnamWorks.com job posting and resume searching)"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 18364 15
# 200 18364
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-tnhh-lotte-world-viet-nam-c363925?fromPage=jobDetail",
#      "ID": 363925,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/70/11136402.png",
#      "Name": "CÔNG TY TNHH LOTTE WORLD VIỆT NAM",
#      "CompanySize": null,
#      "Field": "Nghệ thuật/Giải trí",
#      "Contact": null,
#      "CompanyIntroduction": "LOTTE World, a subsidiary of LOTTE Group, is the global entertainment company operating \"LOTTE World Adventure\" ranked No. 17 in world's best theme park, \"LOTTE World Aquarium\", \"Seoul Sky\" and \"LOTTE Water Park\" etc.\r\nLOTTE World Steps forward to be the leader in both on/offline themed entertainment business in Vietnam as LOTTE World Aquarium Hanoi will be the starting point.",
#      "CompanyAddress": "Hầm B1-B2, Trung tâm thương mại Lotte Mall Hà Nội, số 272 đường Võ Chí Công, Q. Tây Hồ, Hà Nội",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "13rd salary will be provided (Pro-rata for time of employment if work less than 12 months)"
#           },
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Social Insurance, health insurance according to Vietnam Labor Code"
#           },
#           {
#                "Name": "Khác",
#                "Description": "Competitive Salary (negotiation)"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 363925 16
# 200 363925
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-cp-giai-phap-thanh-toan-viet-nam-vnpay-c102274?fromPage=jobDetail",
#      "ID": 102274,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/64/11035048.png",
#      "Name": "Công Ty CP Giải Pháp Thanh Toán Việt Nam (VNPAY)",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Tài Chính",
#      "Contact": "Phòng nhân sự",
#      "CompanyIntroduction": "Công ty Cổ Phần VNPAY SHOP Thương Mại Dịch Vụ được thành lập từ năm 2016, trực thuộc tập đoàn VNLIFE, đang sở hữu nền tảng thương mại điện tử VnShop được tích hợp đầu tiên và duy nhất trên ứng dụng Mobile Banking và Ví điện tử VNPAY.\r\n\r\nNgoài các kênh bán trực tuyến là Website, App Mobile, VnShop là đơn vị duy nhất khai thác kênh bán hàng qua App Mobile banking của các ngân hàng uy tín tại Việt Nam, giúp đối tác tiếp cận > 10 TRIỆU khách hàng sử dụng Mobile Banking\r\n\r\nVới mục tiêu mang đến trải nghiệm mua sắm trực tuyến an toàn, tiện lợi và chất lượng đến cho khách hàng, VNPAY SHOP không ngừng nỗ lực nâng cao chất lượng dịch vụ và sản phẩm mỗi ngày\r\n\r\nLà công ty thành viên thuộc hệ sinh thái của VNPAY, chúng tôi đang không ngừng mở rộng tìm kiếm các ứng viên phù hợp cho vị trí sau đây:",
#      "CompanyAddress": "Tầng 8, số 22, Phố Láng Hạ, Phường Láng Hạ, Quận Đống Đa, Thành phố Hà Nội, Việt Nam",
#      "Welfare": [
#           {
#                "Name": "Lương & Thưởng",
#                "Description": "Mức lương thỏa thuận theo năng lực. Chế độ thưởng vào các dịp lễ Tết, thưởng hàng năm theo thâm niên và kết quả kinh doanh của công ty."
#           },
#           {
#                "Name": "Trợ cấp bổ sung",
#                "Description": "Chế độ đãi ngộ hấp dẫn cạnh tranh với các công ty khác trên thị trường: phục vụ bữa ăn sáng miễn phí, hỗ trợ cơm trưa (40.000đ/ngày), cung cấp hoa quả và đồ uống miễn phí tại văn phòng, hỗ trợ trang điểm cho nhân viên nữ, hỗ trợ ưu đãi cho CBNV mua nhà, thưởng cổ phiếu cho CBNV có nhiều đóng góp cho Công ty…."
#           },
#           {
#                "Name": "Hoạt động kết nối",
#                "Description": "Được tham gia các chương trình teambuilding, nghỉ mát, du xuân, ngày hội gia đình do công ty tổ chức hàng năm tại các địa điểm du lịch, resort cao cấp. Được tham gia nhiều hoạt động tập thể sáng tạo, CLB tennis, bóng đá, bơi lội, cầu lông, bóng bàn, hoạt động thiện nguyện ..."
#           },
#           {
#                "Name": "Chăm sóc sức khỏe gia đình",
#                "Description": "Hưởng đầy đủ các chế độ BHXH, được tham gia bảo hiểm sức khỏe cao cấp theo chính sách riêng của công ty với rất nhiều quyền lợi dành cho người lao động và người thân khi tham gia bảo hiểm."
#           },
#           {
#                "Name": "Cơ hội thăng tiến",
#                "Description": "Môi trường làm việc cởi mở, trẻ trung, thân thiện, nhiều cơ hội thăng tiến trong công việcrong lĩnh vực giải pháp thanh toán."
#           },
#           {
#                "Name": "Đào tạo chuyên nghiệp",
#                "Description": "Cùng học hỏi với 1000 đồng nghiệp trẻ trung thân thiện với bề dày thành tích hoạt động hơn 16 năm"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 102274 17
# 200 102274
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-co-phan-sua-viet-nam-vinamilk-c2811?fromPage=jobDetail",
#      "ID": 2811,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/b0/11208075.png",
#      "Name": "Công Ty Cổ Phần Sữa Việt Nam (Vinamilk)",
#      "CompanySize": "5.000-9.999 nhân viên",
#      "Field": "Hàng tiêu dùng",
#      "Contact": "Ban Tuyển Dụng",
#      "CompanyIntroduction": "Với lịch sử 40 năm hình thành và phát triển, Công ty Cổ phần Sữa Việt Nam (Vinamilk) cam kết mang đến cho cộng đồng nguồn dinh dưỡng và chất lượng cao cấp hàng đầu bằng chính sự trân trọng, tình yêu và trách nhiệm cao của mình với cuộc sống con người và xã hội.\r\n\r\n“Trở thành biểu tượng niềm tin hàng đầu Việt Nam về sản phẩm dinh dưỡng và sức khỏe phục vụ cuộc sống con người“, Vinamilk không ngừng phấn đấu, phát triển, đổi mới và sáng tạo nhằm mang đến cho cộng đồng những giải pháp dinh dưỡng chất lượng quốc tế, đáp ứng nhu cầu cho mọi đối tượng tiêu dùng với các sản phẩm thơm ngon, bổ dưỡng, tốt cho sức khỏe gắn liền với thương hiệu Vinamilk như: Sữa nước Vinamilk, Sữa chua Vinamilk, Sữa bột Vinamilk, Sữa đặc Ông Thọ và Ngôi Sao Phương Nam, Sữa bột Dielac, Bột ăn dặm RiDIELAC, Sữa đậu nành, Nước ép trái cây Vfresh, Kem và Phô mai...\r\n\r\nTính đến giữa tháng 08/2016, Vinamilk đạt mức vốn hóa kỷ lục là 9.2 tỷ USD (vốn hóa thị trường lớn nhất tại Việt Nam) với doanh thu là 1.8 tỷ USD và được xếp thứ 24 trong danh sách FAB 50 năm 2016. Với sự kiện này, Forbes Asia đã nói “Lần này chính Việt Nam đã tạo ra tin tức nóng hổi nhất. Chưa bao giờ có công ty Việt Nam nào được bình chọn vào FAB 50 nhưng năm nay, chính công ty Vinamilk đã làm nên sự thay đổi”.\r\n\r\nBên cạnh đó, theo một báo cáo của Euro monitor về các công ty sữa trên toàn thế giới thì Vinamilk đang đứng thứ 49 trên toàn cầu về doanh thu các sản phẩm sữa trong năm 2015 (ước tính của KPMG theo số liệu của Euro Monitor). Doanh thu này hiện cao hơn 18% so với mức doanh thu trung bình của các công ty sữa ở Châu Á. Đặc biệt, Vinamilk còn được đánh giá là công ty đứng đầu về tính thanh khoản ở các khu vực. Đây chính là minh chứng cho sự kinh doanh có hiệu quả và nền tảng tài chính vững mạnh của Vinamilk trong suốt 40 năm qua.\r\n\r\nTrong thời gian tới Vinamilk sẽ vẫn chú trọng giữ vững thị trường nội địa, song song với việc tìm kiếm các cơ hội mở rộng ở nước ngoài. Hiện nay ngoài 10 trang trại và 13 nhà máy trong nước, Vinamilk còn có 3 nhà máy tại Mỹ, New Zeland, Campuchia, 1 công ty con tại Ba Lan và đang xúc tiến đẩy mạnh xuất khẩu ở các thị trường mới như Thái Lan, Myanmar và Châu Phi.\r\n\r\nNgoài kết quả kinh doanh ấn tượng, Vinamilk luôn quan tâm đến các hoạt động xã hội vì cộng đồng và sự phát triển của trẻ em Việt Nam, thông qua các chương trình như: Quỹ sữa \"Vươn Cao Việt Nam” với mong muốn “mọi trẻ em đều có quyền được uống sữa mỗi ngày”; Quỹ “Một triệu cây xanh cho Việt Nam” vì một Việt Nam xanh tươi, cùng nhiều hoạt động hỗ trợ cộng đồng khác.\r\n\r\n \r\nVì sao làm việc với chúng tôi?\r\n\r\nHơn 40 năm hình thành và phát triển, trở thành một trong những thương hiệu hàng đầu Việt Nam và đang vươn tầm ra quốc tế, chúng tôi luôn hiểu rằng con người là yếu tố quyết định đối với sự thành công và phát triển của Công ty. Tại Vinamilk, sự nghiệp của các bạn sẽ được phát triển cùng với sự lớn mạnh không ngừng của chúng tôi.\r\n\r\nĐến với Vinamilk, bạn sẽ có được điều gì? \r\n\r\nMôi trường chuyên nghiệp, công việc đầy thách thức và cơ hội làm việc với những người giàu kinh nghiệm, là nơi tốt nhất để bạn chọn lựa cho con đường phát triển sự nghiệp của mình. Chúng tôi luôn cam kết tạo mọi điều kiện thuận lợi nhất giúp bạn đạt được mục tiêu nghề nghiệp. Vinamilk là nơi bạn có thể thỏa sức sáng tạo, đưa những kiến thức và kinh nghiệm vào thực tế nhằm góp phần xây dựng và phát triển Công ty. Ngoài ra, chúng tôi còn mang lại:\r\n\r\n•\tChương trình đào tạo giúp nhân viên phát triển và đạt được mục tiêu nghề nghiệp\r\n•\tChế độ lương bổng và đãi ngộ xứng đáng\r\n•\tNhiều cơ hội công việc mới cùng với sự phát triển không ngừng của công ty\r\n•\tNền văn hóa tạo cảm hứng làm việc và sáng tạo\r\n\r\n \r\nGiải thưởng:\r\n\r\nVới những nổ lực và phát triển không ngừng, Vinamilk đã vươn cao - Trở thành điểm sáng kinh tế không chỉ Việt Nam mà còn vươn tầm thế giới. Vinamilk đã trở thành một trong những Doanh nghiệp hàng đầu của Việt Nam trên tất cả m ...
#      "CompanyAddress": "Số 10, Tân Trào, P. Tân Phú, Q.7, Tp. HCM",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Chế độ lương bổng và đãi ngộ xứng đáng"
#           },
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Chế độ chăm sóc sức khỏe toàn diện"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Chương trình đào tạo giúp nhân viên phát triển"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 2811 18
# 200 2811
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-co-phan-ky-thuat-xay-dung-dinco-c397004?fromPage=jobDetail",
#      "ID": 397004,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/d4/11338120.png",
#      "Name": "Công Ty Cổ Phần Kỹ Thuật Xây Dựng DINCO",
#      "CompanySize": null,
#      "Field": "Kỹ thuật xây dựng/Cơ sở hạ tầng",
#      "Contact": "HR Department",
#      "CompanyIntroduction": "Ra đời từ năm 2004, DINCO đã khẳng định được sự phát triển bền vững trên nền tảng Trung Thực & Đạo Đức với hơn 70% khách hàng là các Chủ đầu tư nước ngoài. Chúng tôi định hướng sẽ trở thành công ty đại chúng và niêm yết cổ phiếu trên sàn giao dịch chứng khoán Sài Gòn vào năm 2017.\r\n\r\nDINCO - Lựa chọn Hàng Đầu đối với các khách hàng trong lĩnh vực xây dựng nhà máy công nghiệp, cao ốc, khách sạn, resort và công trình giao thông. Công ty thuộc hình thức sở hữu tư nhân có trụ sở chính tại thành phố Đà Nẵng và văn phòng TP.HCM với hơn 400 nhân viên và trên 3000 Công nhân.\r\n\r\n“Con người” là nền tảng để phát triển công ty và tạo ra lợi nhuận. Với tiêu chí đó, DINCO đã,đang và không ngừng tập trung thu hút, khai thác, bồi dưõng, phát triển đội ngũ nhân lực. Nhằm tiếp tục khẳng định công ty chúng tôi không chỉ là địa chỉ uy tín cho các nhà đầu tư trong và ngoài nước mà còn là nơi đóng góp, thể hiện và trau dồi đáng tin cậy đối với toàn thể nhân viên công ty.\r\n\r\nĐể đáp ứng nhu cầu nhân sự cho các dự án lớn sắp đến, chúng tôi đang cần chiêu mộ tài năng với vị trí Nhân viên Kinh Doanh. Gia nhập vào DINCO, chúng tôi cam kết bạn sẽ nhận được:\r\n• Mức thu nhập hấp dẫn xứng đáng với năng lực.\r\n• Lương thưởng tháng 13.\r\n• Thưởng hoa hồng theo dự án.\r\n• Môi trường làm việc thách thức tạo động lực cho sự thăng tiến trong nghề nghiệp.\r\n• Các chương trình đào tạo liên tục được áp dung.\r\n• Chính sách trọng dụng và phát triển nhân tài.\r\n• Lộ trình thăng tiến hấp dẫn.\r\nVà rất nhiều đãi ngộ khác đang chờ đón bạn!\r\n\r\n* Website: http://dinco.com.vn/gioi-thieu/nguon-luc/\r\n\r\nCompany Size: 100-499",
#      "CompanyAddress": "Tầng 2, Tòa nhà Danabook, 76-78 Bạch Đằng, Phường Hải Châu I, Quận Hải Châu, TP Đà Nẵng",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Lương thưởng tương xứng với năng lực"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Được tham gia các chương trình đào tạo nâng cao kỹ năng"
#           },
#           {
#                "Name": "Du lịch",
#                "Description": "Du lịch, tham quan các dự án nước ngoài"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 397004 19
# 200 397004
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-cp-giai-phap-thanh-toan-viet-nam-vnpay-c102274?fromPage=jobDetail",
#      "ID": 102274,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/64/11035048.png",
#      "Name": "Công Ty CP Giải Pháp Thanh Toán Việt Nam (VNPAY)",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Tài Chính",
#      "Contact": "Phòng nhân sự",
#      "CompanyIntroduction": "Công ty Cổ Phần VNPAY SHOP Thương Mại Dịch Vụ được thành lập từ năm 2016, trực thuộc tập đoàn VNLIFE, đang sở hữu nền tảng thương mại điện tử VnShop được tích hợp đầu tiên và duy nhất trên ứng dụng Mobile Banking và Ví điện tử VNPAY.\r\n\r\nNgoài các kênh bán trực tuyến là Website, App Mobile, VnShop là đơn vị duy nhất khai thác kênh bán hàng qua App Mobile banking của các ngân hàng uy tín tại Việt Nam, giúp đối tác tiếp cận > 10 TRIỆU khách hàng sử dụng Mobile Banking\r\n\r\nVới mục tiêu mang đến trải nghiệm mua sắm trực tuyến an toàn, tiện lợi và chất lượng đến cho khách hàng, VNPAY SHOP không ngừng nỗ lực nâng cao chất lượng dịch vụ và sản phẩm mỗi ngày\r\n\r\nLà công ty thành viên thuộc hệ sinh thái của VNPAY, chúng tôi đang không ngừng mở rộng tìm kiếm các ứng viên phù hợp cho vị trí sau đây:",
#      "CompanyAddress": "Tầng 8, số 22, Phố Láng Hạ, Phường Láng Hạ, Quận Đống Đa, Thành phố Hà Nội, Việt Nam",
#      "Welfare": [
#           {
#                "Name": "Lương & Thưởng",
#                "Description": "Mức lương thỏa thuận theo năng lực. Chế độ thưởng vào các dịp lễ Tết, thưởng hàng năm theo thâm niên và kết quả kinh doanh của công ty."
#           },
#           {
#                "Name": "Trợ cấp bổ sung",
#                "Description": "Chế độ đãi ngộ hấp dẫn cạnh tranh với các công ty khác trên thị trường: phục vụ bữa ăn sáng miễn phí, hỗ trợ cơm trưa (40.000đ/ngày), cung cấp hoa quả và đồ uống miễn phí tại văn phòng, hỗ trợ trang điểm cho nhân viên nữ, hỗ trợ ưu đãi cho CBNV mua nhà, thưởng cổ phiếu cho CBNV có nhiều đóng góp cho Công ty…."
#           },
#           {
#                "Name": "Hoạt động kết nối",
#                "Description": "Được tham gia các chương trình teambuilding, nghỉ mát, du xuân, ngày hội gia đình do công ty tổ chức hàng năm tại các địa điểm du lịch, resort cao cấp. Được tham gia nhiều hoạt động tập thể sáng tạo, CLB tennis, bóng đá, bơi lội, cầu lông, bóng bàn, hoạt động thiện nguyện ..."
#           },
#           {
#                "Name": "Chăm sóc sức khỏe gia đình",
#                "Description": "Hưởng đầy đủ các chế độ BHXH, được tham gia bảo hiểm sức khỏe cao cấp theo chính sách riêng của công ty với rất nhiều quyền lợi dành cho người lao động và người thân khi tham gia bảo hiểm."
#           },
#           {
#                "Name": "Cơ hội thăng tiến",
#                "Description": "Môi trường làm việc cởi mở, trẻ trung, thân thiện, nhiều cơ hội thăng tiến trong công việcrong lĩnh vực giải pháp thanh toán."
#           },
#           {
#                "Name": "Đào tạo chuyên nghiệp",
#                "Description": "Cùng học hỏi với 1000 đồng nghiệp trẻ trung thân thiện với bề dày thành tích hoạt động hơn 16 năm"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 102274 20
# 200 102274
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/chicilon-media-c104721?fromPage=jobDetail",
#      "ID": 104721,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/5b/11100928.png",
#      "Name": "Chicilon Media",
#      "CompanySize": "100-499 nhân viên",
#      "Field": "Truyền thông/Báo chí/Quảng cáo",
#      "Contact": "Ms. Lily",
#      "CompanyIntroduction": "Công ty Cổ phần Công Nghệ Thông tin Truyền Thông Thiên Hy Long Việt Nam (Chicilon Media) được thành lập vào tháng 9 năm 2006, với số vốn điều lệ lên tới 32 triệu Đô la Mỹ. Công ty đặt trụ sở chính tại TP.HCM, đồng thời sở hữu 2 chi nhánh ở Hà Nội và Đà Nẵng. Lĩnh vực kinh doanh chính của công ty là cung cấp cho doanh nghiệp giải pháp truyền thông hiệu quả trong việc tiếp thị thương hiệu và quảng bá sản phẩm. Chicilon sở hữu mạng lưới truyền thông phủ sóng rộng khắp các kênh thang máy tòa nhà, kênh sân bay và kênh siêu thị.\r\n\r\nSau 18 năm hoạt động và phát triển không ngừng, Chicilon Media đã thành công xây dựng nên 5 kênh truyền thông lớn, bao gồm: kênh Tivi thang máy tòa nhà, kênh Poster thang máy tòa nhà, kênh Poster siêu thị, kênh Poster sân bay và hệ thống kênh LED lớn sân bay; mỗi ngày tiếp cận hơn 40 triệu lượt người tiêu dùng chủ lực tại thành phố cùng với mức doanh thu hàng năm lên tới 53 triệu Đô la Mỹ.\r\n\r\nChicilon Media đã cùng 18 doanh nghiệp lớn gồm Bia Heineken, Unilever, Bia Sài Gòn, Bia Tiger, v.v... gia nhập Tổ chức Tiếp thị Thế giới (MMA) và trở thành một trong những thành viên nằm trong Ban điều hành của tổ chức này, đồng thời cũng là công ty truyền thông duy nhất tại Việt Nam gia nhập Hiệp hội quảng cáo ngoài trời thế giới (WOO).",
#      "CompanyAddress": "17th Floor, Vietcombank Tower, No. 5 Me Linh Square, Ben Nghe Ward, District 1, Ho Chi Minh City, Vietnam",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Lương cơ bản tùy theo năng lực + hoa hồng + Phụ cấp cơm trưa, gửi xe"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Được làm việc trong môi trường truyền thông trẻ trung, năng động, chuyên nghiệp"
#           },
#           {
#                "Name": "Hoạt động nhóm",
#                "Description": "Chế độ Team building, du lịch nghỉ mát nước ngoài"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 104721 21
# 200 104721
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-cp-giai-phap-thanh-toan-viet-nam-vnpay-c102274?fromPage=jobDetail",
#      "ID": 102274,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/64/11035048.png",
#      "Name": "Công Ty CP Giải Pháp Thanh Toán Việt Nam (VNPAY)",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Tài Chính",
#      "Contact": "Phòng nhân sự",
#      "CompanyIntroduction": "Công ty Cổ Phần VNPAY SHOP Thương Mại Dịch Vụ được thành lập từ năm 2016, trực thuộc tập đoàn VNLIFE, đang sở hữu nền tảng thương mại điện tử VnShop được tích hợp đầu tiên và duy nhất trên ứng dụng Mobile Banking và Ví điện tử VNPAY.\r\n\r\nNgoài các kênh bán trực tuyến là Website, App Mobile, VnShop là đơn vị duy nhất khai thác kênh bán hàng qua App Mobile banking của các ngân hàng uy tín tại Việt Nam, giúp đối tác tiếp cận > 10 TRIỆU khách hàng sử dụng Mobile Banking\r\n\r\nVới mục tiêu mang đến trải nghiệm mua sắm trực tuyến an toàn, tiện lợi và chất lượng đến cho khách hàng, VNPAY SHOP không ngừng nỗ lực nâng cao chất lượng dịch vụ và sản phẩm mỗi ngày\r\n\r\nLà công ty thành viên thuộc hệ sinh thái của VNPAY, chúng tôi đang không ngừng mở rộng tìm kiếm các ứng viên phù hợp cho vị trí sau đây:",
#      "CompanyAddress": "Tầng 8, số 22, Phố Láng Hạ, Phường Láng Hạ, Quận Đống Đa, Thành phố Hà Nội, Việt Nam",
#      "Welfare": [
#           {
#                "Name": "Lương & Thưởng",
#                "Description": "Mức lương thỏa thuận theo năng lực. Chế độ thưởng vào các dịp lễ Tết, thưởng hàng năm theo thâm niên và kết quả kinh doanh của công ty."
#           },
#           {
#                "Name": "Trợ cấp bổ sung",
#                "Description": "Chế độ đãi ngộ hấp dẫn cạnh tranh với các công ty khác trên thị trường: phục vụ bữa ăn sáng miễn phí, hỗ trợ cơm trưa (40.000đ/ngày), cung cấp hoa quả và đồ uống miễn phí tại văn phòng, hỗ trợ trang điểm cho nhân viên nữ, hỗ trợ ưu đãi cho CBNV mua nhà, thưởng cổ phiếu cho CBNV có nhiều đóng góp cho Công ty…."
#           },
#           {
#                "Name": "Hoạt động kết nối",
# ...
#      "CompanyAddress": "Sailing Tower, số 111A Pasteur, Phường Bến Nghé, Quận 1, TP. Hồ Chí Minh",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Thưởng theo hiệu quả công việc"
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "15 ngày nghỉ phép năm"
#           },
#           {
#                "Name": "Du lịch",
#                "Description": "Du lịch hè hàng năm theo chính sách ngân hàng"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 36138 75
# 200 36138
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-tnhh-van-tai-va-giao-nhan-gac-viet-nam-c374408?fromPage=jobDetail",
#      "ID": 374408,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/df/11200496.png",
#      "Name": "Công ty TNHH Vận tải và Giao nhận GAC Việt Nam",
#      "CompanySize": null,
#      "Field": "Nhập khẩu/Xuất khẩu",
#      "Contact": null,
#      "CompanyIntroduction": "",
#      "CompanyAddress": "",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "13th month salary & year-end bonus by individual ability and company’s performance."
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "16 days of annual leaves"
#           },
#           {
#                "Name": "Khác",
#                "Description": "SHUI on 100% salary under Labor Contract"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 374408 76
# 200 374408
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/tp-inc-hanoi-business-center-c196905?fromPage=jobDetail",
#      "ID": 196905,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/ee/11294915.png",
#      "Name": "TP Inc. - Hanoi Business Center",
#      "CompanySize": "10.000-19.999 nhân viên",
#      "Field": "Sản xuất",
#      "Contact": "Mr. Nghia",
#      "CompanyIntroduction": "TP Inc. (Pan-Pacific), a listed clothing manufacturing corporation, was established in 1972 and has since produced apparel as an OEM and an ODM. We have exported our products around the world, including to the Americas, Europe, and Japan.\r\n\r\nWhile achieving sales figures of more than 800 billion KRW annually, the company has consolidated its presence with the joint operations of PRAUDEN and SOFRAUM, two number-one brands specializing in downs (a down-specialized brand and a down bedding brand, respectively) in Korea.\r\n\r\nAnother area of focus for TP has been the fostering of chemical-fibers-specialized brands, including SYNCLOUD and ABSOLON. In addition, the company has been motivated to expand into new business areas as well.\r\n\r\nIn Vietnam, TP Inc currently has 7 factories based in Hanoi, Bac Ninh, Bac Giang, Vinh Phuc and Thanh Hoa. We also have 04 Representative Offices and Technical Center in Hanoi and Ho Chi Minh.\r\n\r\nMore about us, please visit: tp-inc.com",
#      "CompanyAddress": "108 Nguyen Hoang, My Dinh 2, Nam Tu Liem, Hanoi",
#      "Welfare": [
#           {
#                "Name": "Good career path development. Competitive & attractive salary based on candidates qualifications.",
#                "Description": "Opportunities to work directly with Global clients, and suppliers."
#           },
#           {
#                "Name": "Opportunity to work for one of biggest apparel vendors over the world.",
#                "Description": "Good career path development."
#           },
#           {
#                "Name": "12 annual leave days, public holidays according to Vietnamese Labor Law.",
#                "Description": "Competitive & attractive salary based on candidate's qualifications."
#           },
#           {
#                "Name": "Working environment",
#                "Description": "Young, dynamic & challenging working environment."
#           },
#           {
#                "Name": "Team building",
#                "Description": "Team buildiing and outdoor activities"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 196905 77
# 200 196905
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-co-phan-technokom-c275767?fromPage=jobDetail",
#      "ID": 275767,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/50/10544751.png",
#      "Name": "Công Ty Cổ Phần Technokom",
#      "CompanySize": null,
#      "Field": "Sản xuất",
#      "Contact": "ms. Hạnh",
#      "CompanyIntroduction": "Công ty cổ phần TECHNOKOM là doanh nghiệp hoạt động trong lĩnh vực sản xuất phụ tùng ô tô, xe máy và gia công cơ khí.\r\n\r\nHiện nay, Technokom là nhà cung cấp truyền thống cho chuỗi cung ứng của Honda Việt Nam; Chúng tôi cũng đang sản xuất những mặt hàng xuất khẩu cho tập đoàn ITP (hàng chân bàn sofa, inox cao cấp), Tập đoàn ICSN (hàng phụ tùng ô tô); ngoài ra khách hàng mục tiêu Công ty hướng tới là các doanh nghiệp sản xuất các sản phẩm ngoài ngành xe máy như: Điện lạnh, nội thất, ô tô ... và liên doanh, liên kết với các đối tác để sản xuất, xuất khẩu sản phẩm ra thị trường nước ngoài.\r\n\r\nTrong công cuộc chinh phục những lĩnh vực mới và hướng tới những đỉnh cao kỹ thuật trong ngành gia công cơ khí. Công ty chúng tôi luôn mong muốn đón nhận những luồng gió mới, những người có chí hướng muốn khẳng định bản thân với tài năng của mình trở thành những nhân sự cốt cán xây dựng công ty vững mạnh với mục tiêu chiến lược nói trên.\r\n\r\nTừ định hướng phát triển đó, trong năm tới Công ty cổ phần Technokom đang mở rộng đội ngũ cán bộ nòng cốt nhằm nghiên cứu và phát triển sản phẩm mới, có tính cạnh tranh cao tại thị trường trong và ngoài nước.\r\n\r\nTham khảo thêm thông tin công ty tại địa chỉ website: https://www.technokom.com.vn/",
#      "CompanyAddress": "Khu công nghiệp Phố Nối A, Văn Lâm, Hưng Yên",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Cơ chế nâng lương, nâng bậc định kỳ hàng năm và đột xuất theo kết quả làm việc"
#           },
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Được đào tạo và phát triển trong và ngoài Công ty"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Chế độ tham quan, nghỉ mát, khám sức khoẻ định kỳ; chế độ công  đoàn … đầy đủ hàng năm"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 275767 78
# 200 275767
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/cong-ty-tnhh-providence-enterprise-viet-nam-c323694?fromPage=jobDetail",
#      "ID": 323694,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/86/10925407.png",
#      "Name": "Công Ty TNHH Providence Enterprise (Việt Nam)",
#      "CompanySize": null,
#      "Field": "Sản xuất",
#      "Contact": null,
#      "CompanyIntroduction": "https://www.providencehk.com/ là tập đoàn sản xuất đồ điện gia dụng và thiết bị y tế hàng đầu thế giới được thành lập năm 1992. \r\nhttps://www.providencehk.com/是家具电器和医疗设备制造的领先集团，成立于1992年。\r\nCông ty TNHH PROVIDENCE ENTERPRISE VIÊT NAM đang xây dựng nhà máy mới tại KCN An Dương, Hải Phòng với quy mô 1000 công nhân, dự định giữa tháng 6/2020  đi vào sản xuất. Để đáp ứng nhu cầu sản xuất, công ty đang cần tuyển gấp một số vị trí quản lý như sau :\r\n汇进（越南）实业有限公司正在海防、安阳工业区建立新工厂，规模为1000名员工，预定2020年6月中旬进行生产。为答应生产要求，公司需要招聘一些管理职位，如下：\r\n\r\nhttps://www.providencehk.com/ là tập đoàn sản xuất đồ điện gia dụng và thiết bị y tế hàng đầu thế giới được thành lập năm 1992. \r\n\r\nCông ty TNHH Providence Enterprise (Việt Nam) đang xây dựng nhà máy mới tại KCN An Dương, Hải Phòng với quy mô 1000 công nhân. Để đáp ứng nhu cầu sản xuất, công ty đang cần tuyển gấp một số vị trí quản lý",
#      "CompanyAddress": "Thửa đất B26 thuộc lô đất CN3, Khu Công nghiệp An Dương, Xã Hồng Phong, Huyện An Dương, Hải Phòng, Việt Nam",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Lương thỏa thuận, hấp dẫn, tương xứng với năng lực và vị trí ứng tuyển"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Môi trường làm việc thân thiện, năng động, chuyên nghiệp, ổn định, lâu dài"
#           },
#           {
#                "Name": "Giải thưởng",
#                "Description": "Cơ hội thăng tiến, phát triển bản thân"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 323694 79
# 200 323694
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/kinderworld-international-group-singapore-international-school-c9718?fromPage=jobDetail",
#      "ID": 9718,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/d1/11152798.png",
#      "Name": "Kinderworld International Group (Singapore International School)",
#      "CompanySize": null,
#      "Field": "Giáo dục/Đào Tạo",
#      "Contact": "Human Resources Department",
#      "CompanyIntroduction": "About KinderWorld International Group KinderWorld International Group, rooted in 1986 in Singapore, believes in offering a combination of Eastern values with an International outlook on education. From our first preschool, KinderWorld International Group now operates 16 campuses in Vietnam, offering through-train education from Preschool to High School, and University Foundation. We believe that education should equip our students with the essential knowledge and skills needed for a technology-driven and globalized world while preserving and nurturing the significant values and cultures of Asia. Our students’ excellent achievements reflect KinderWorld’s commitment to prepare our students for life-long learning and global citizenship. For more information, visit us at: \r\n\r\nhttp://kinderworld.net",
#      "CompanyAddress": "Hà Nội",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Attractive Salary"
#           },
#           {
#                "Name": "Nghỉ phép",
#                "Description": "Additional Annual Leave, 24/7 insurance coverage"
#           },
#           {
#                "Name": "Trông trẻ",
#                "Description": "Attractive discount for staff's children studying at Singapore International School system"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 9718 80
# 200 9718
# {
#      "Url": "https://www.vietnamworks.com/nha-tuyen-dung/truong-dai-hoc-nguyen-tat-thanh-c298516?fromPage=jobDetail",
#      "ID": 298516,
#      "Logo": "https://images.vietnamworks.com/pictureofcompany/88/10887022.png",
#      "Name": "Trường Đại Học Nguyễn Tất Thành",
#      "CompanySize": "1.000-4.999 nhân viên",
#      "Field": "Giáo dục/Đào Tạo",
#      "Contact": null,
#      "CompanyIntroduction": "https://ntt.edu.vn/\n\nTrường ĐH Nguyễn Tất Thành có quy mô đào tạo khoảng 20.000 sinh viên với 15 khoa, 48 chương trình đào tạo bậc đại học thuộc 5 khối ngành: Sức khỏe, Công nghệ - Kĩ thuật, Kinh tế, Xã hội - Nhân văn, Mỹ thuật. Trải qua hơn 20 năm hình thành và phát triển, Nhà trường đã được Bộ Giáo dục và Đào tạo công nhận đạt chuẩn kiểm định chất lượng và được tổ chức QS (QS Quacquarelli Symonds Ltd) chính thức công nhận đạt chuẩn chất lượng 4 sao.\n\n1. Tầm nhìn\nĐến năm 2025, Trường Đại học Nguyễn Tất Thành là một trường đại học ứng dụng và thực hành, đa ngành, đa bậc học, gắn với nhu cầu phát triển trong và ngoài nước, đạt chuẩn khu vực và quốc tế.\n\n2. Sứ mạng\nTrường Đại học Nguyễn Tất Thành cam kết cung cấp nguồn nhân lực có chất lượng, có sức cạnh tranh cao trên thị trường lao động trong và ngoài nước thông qua đào tạo, nghiên cứu và phục vụ cộng đồng, xã hội dựa trên liên minh chiến lược gắn kết với các doanh nghiệp và các viện nghiên cứu.\n\n3. Mục tiêu\nTrường ĐH NTT theo định hướng ứng dụng và thực hành, đáp ứng nhu cầu giáo dục đại chúng thông qua việc tạo lập một môi trường học tập tích cực và trải nghiệm thực tiễn cho mọi SV, trang bị cho người học năng lực tự học, tinh thần sáng tạo khởi nghiệp, có trách nhiệm với cộng đồng, hội nhập khu vực và toàn cầu.\n\n4. Giá trị cốt lõi: \nĐoàn kết (một tập thể thống nhất hoạt động vì mục tiêu chung)\nHội nhập (với chuẩn trong nước, khu vực, và thế giới);\nNăng động (trong học tập, nghiên cứu, và làm việc);\nTrí tuệ (với tâm trong, trí sáng, xử trí mọi vấn đề thông minh);\nTrách nhiệm (với bản thân, gia đình, cộng đồng, xã hội, và quốc tế).\n\n5. Triết lý đào tạo:\nTrường ĐH Nguyễn Tất Thành với triết lý giáo dục “Thực học –Thực hành – Thực danh – Thực nghiệp”\nNhà trường theo quan điểm lấy người học làm trung tâm, từ đó nêu ra triết lý giáo dục của trường là “Thực học – Thực hành – Thực danh – Thực nghiệp”. Nhà trường tin rằng: “Người học hình thành năng lực thông qua môi trường học thuật được tạo lập và gắn kết với doanh nghiệp trong các hoạt động nghiên cứu, ứng dụng và phục vụ cộng đồng. Việc trải nghiệm trong môi trường thực tiễn giúp người học khám phá kiến thức, phát triển kỹ năng, định hướng tương lai, hình thành mong muốn đóng góp cho cộng đồng và tạo dựng uy tín cá nhân bằng sự chuyên nghiệp và đạo đức nghề nghiệp”.\n\n6. Định hướng phát triển\nĐến năm 2020 Trường ĐH Nguyễn Tất Thành trở thành trường đại học ứng dụng thực hành, đạt chuẩn quốc gia và có uy tín trong nước và quốc tế.\nTrở thành một trong số những trường đại học thuộc top 50 của Asean\nMột số ngành/lĩnh vực đạt top 500 của châu Á, từng bước sánh vai với các trường đại học tiên tiến của khu vực và thế giới.\nĐạt chuẩn quốc tế QS Stars Anh Quốc 4 sao\nVào top 300 các trường đại học Châu Á với chú trọng về các lĩnh vực chất lượng do QS quy định như sau:\n            + Chất lượng nghiên cứu (Research quality)\n            + Chất lượng giảng dạy (Teaching Quality)\n            + Mức độ quốc tế hóa (Internationalisation)",
#      "CompanyAddress": "300A Nguyễn Tất Thành, Phường 13, Quận 4, TP.HCM",
#      "Welfare": [
#           {
#                "Name": "Thưởng",
#                "Description": "Thưởng theo năng lực và được đào tạo, cơ hội thăng tiến cao"
#           },
#           {
#                "Name": "Khám sức khoẻ",
#                "Description": "Có chế độ công tác phí theo quy định của nhà trường"
#           },
#           {
#                "Name": "Đào tạo",
#                "Description": "Hưởng đầy đủ các quyền lợi theo quy định theo Bộ luật lao động (BHXH, BHYT, BHTN)"
#           }
#      ]
# }
# 200 Cập nhật thông tin thành công. 298516 81

# %%
# # Lưu vào tệp JSON
with open("sample_vietnamworks_company_v4.json", "w", encoding="utf-8") as json_file:
    json.dump(output, json_file, ensure_ascii=False, indent=5, default=default_converter)
